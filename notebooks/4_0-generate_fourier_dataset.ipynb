# %%
import os
import pandas as pd
import glob
import json
version = "v5"
data_path = f"../data/interim/{version}"
dataset_target_path = "../data/processed"

# %%
from lib import read_dataset
data_on_raw, data_off_raw = read_dataset(data_path, classes = 2)
# Out:
# 0 milenkosRoomTrafficBed2
# 1 NadasKitchenWithTraffic
# 2 PiXmilenkosRoomTrafficTable2
# 3 NadasLivingRoomWithTrafficOrient2
# 4 milenkosRoomTrafficBed3
# 5 spelaMilenkosKitchenTrafficTable1
# 6 PiXmilenkosRoomTrafficTable6
# 7 milenkosRoomTrafficTable3
# 8 spelaMilenkosRoomTrafficTable3
# 9 spelaMilenkosRoomTrafficTable1
# 10 spelaMilenkosKitchenTrafficTable3
# 11 NadasKitchenWithTrafficOrient2
# 12 LATERNAWithTruffic
# 13 PiXmilenkosRoomTrafficTable3
# 14 PiXmilenkosRoomTrafficTable7
# 15 NadasBathroomWithTrafficOrient1
# 16 NadasLivingRoomWithTrafficOrient3
# 17 milenkosRoomTrafficTable2
# 18 spelaMilenkosKitchenTrafficTable4
# 19 milenkosRoomTrafficBed1
# 20 milenkosRoomWithTrafficDifferentOrentationWithPousesInRuns2
# 21 LATERNAresorantWithTrafic
# 22 milenkosRoomEithTrafficDifferentOrentationWithPousesInRuns3
# 23 spelaMilenkosRoomTrafficTable2
# 24 milenkosRoomTrafficTable
# 25 milenkosRoomWithTrafficDifferentOrentationWithPousesInRuns
# 26 MihasLivingRoom
# 27 NadasLivingRoomWithTraffic
# 28 NadasKitchenWithTrafficOrient3
# 29 PiXmilenkosRoomTrafficTable1
# 30 PiXmilenkosRoomTrafficTable4
# 31 PiXmilenkosRoomTrafficTable5
# 32 LATERNAWithTraffic2
# 33 spelaMilenkosKitchenTrafficTable2

# %%
from lib import add_intensity_to_dataset
add_intensity_to_dataset(data_on_raw)
add_intensity_to_dataset(data_off_raw)

# %%
from collections import ChainMap
def subsamples(df: pd.DataFrame, name: str, window=2000, stride=10):
    return {f"{name}_{i:03d}": df[start:start+window] for i, start in enumerate(range(0,df.shape[0]-window, stride))}

data_on = dict(ChainMap(*[subsamples(df, name) for name,df in data_on_raw.items()]))
data_off = dict(ChainMap(*[subsamples(df, name) for name,df in data_off_raw.items()]))

# %%
len(data_on.keys())
# Out:
# 12778

# %%
data_on[list(data_on.keys())[0]]
# Out:
#       Unnamed: 0  X_UnCal    Y_UnCal    Z_UnCal     X_Bias  Y_Bias     Z_Bias  \
# 0              0    -1.92  28.619999 -176.09999  56.879997   -10.8 -96.299995
# 1              1    -2.28  28.500000 -176.28000  56.879997   -10.8 -96.299995
# 2              2    -1.98  28.740000 -176.16000  56.879997   -10.8 -96.299995
# 3              3    -1.74  28.920000 -175.62000  56.879997   -10.8 -96.299995
# 4              4    -1.98  28.500000 -175.56000  56.879997   -10.8 -96.299995
# ...          ...      ...        ...        ...        ...     ...        ...
# 1995        1995    -2.46  28.439999 -176.34000  56.879997   -10.8 -96.299995
# 1996        1996    -2.04  27.960000 -175.86000  56.879997   -10.8 -96.299995
# 1997        1997    -1.92  28.380000 -175.50000  56.879997   -10.8 -96.299995
# 1998        1998    -2.04  28.740000 -174.95999  56.879997   -10.8 -96.299995
# 1999        1999    -1.86  29.039999 -174.48000  56.879997   -10.8 -96.299995
#
#             time_UnCal  Accuracy         device_id  location   Intensity  \
# 0     3386562414059665         1  e08d976ac75c011e  Kitchen2  178.420843
# 1     3386562424057665         1  e08d976ac75c011e  Kitchen2  178.583557
# 2     3386562434056665         1  e08d976ac75c011e  Kitchen2  178.500010
# 3     3386562444055331         1  e08d976ac75c011e  Kitchen2  177.993759
# 4     3386562454054331         1  e08d976ac75c011e  Kitchen2  177.869289
# ...                ...       ...               ...       ...         ...
# 1995  3386582363453304         1  e08d976ac75c011e  Kitchen2  178.635609
# 1996  3386582373452070         1  e08d976ac75c011e  Kitchen2  178.080495
# 1997  3386582383450836         1  e08d976ac75c011e  Kitchen2  177.790216
# 1998  3386582393449536         1  e08d976ac75c011e  Kitchen2  177.316517
# 1999  3386582403448302         1  e08d976ac75c011e  Kitchen2  176.889942
#
#       Bias_Intensity
# 0         112.363976
# 1         112.363976
# 2         112.363976
# 3         112.363976
# 4         112.363976
# ...              ...
# 1995      112.363976
# 1996      112.363976
# 1997      112.363976
# 1998      112.363976
# 1999      112.363976
#
# [2000 rows x 13 columns]

# %%
from lib import spectral_dataset
dataset_on = spectral_dataset(data_on, 6, vec_len=50, column='Intensity', experiment_duration=10)
dataset_off = spectral_dataset(data_off, 5, vec_len=50, column='Intensity', experiment_duration=10)

# %%
dataset_on#.iloc[0,:].to_list()
# Out:
#                                         name   location         device_id  \
# 0      spelaMilenkosKitchenTrafficTable2_000   Kitchen2  e08d976ac75c011e
# 1      spelaMilenkosKitchenTrafficTable2_001   Kitchen2  e08d976ac75c011e
# 2      spelaMilenkosKitchenTrafficTable2_002   Kitchen2  e08d976ac75c011e
# 3      spelaMilenkosKitchenTrafficTable2_003   Kitchen2  e08d976ac75c011e
# 4      spelaMilenkosKitchenTrafficTable2_004   Kitchen2  e08d976ac75c011e
# ...                                      ...        ...               ...
# 12773            milenkosRoomTrafficBed2_552  DormRoom1  029a77f196804217
# 12774            milenkosRoomTrafficBed2_553  DormRoom1  029a77f196804217
# 12775            milenkosRoomTrafficBed2_554  DormRoom1  029a77f196804217
# 12776            milenkosRoomTrafficBed2_555  DormRoom1  029a77f196804217
# 12777            milenkosRoomTrafficBed2_556  DormRoom1  029a77f196804217
#
#        label           1         2         3         4         5         6  \
# 0          6  357.073867  0.501986  0.374244  0.413952  0.398201  0.358265
# 1          6  357.055284  0.517211  0.378951  0.435080  0.401929  0.367361
# 2          6  357.061322  0.512444  0.376059  0.425456  0.399774  0.361710
# 3          6  357.044205  0.523986  0.381477  0.438351  0.396000  0.351603
# 4          6  357.026194  0.533029  0.379994  0.419989  0.397748  0.359882
# ...      ...         ...       ...       ...       ...       ...       ...
# 12773      6  188.682892  0.211221  0.270201  0.391870  0.391660  0.326675
# 12774      6  188.685394  0.217305  0.270533  0.395352  0.390222  0.328632
# 12775      6  188.681095  0.207935  0.276403  0.386915  0.387346  0.347042
# 12776      6  188.687770  0.216277  0.265623  0.384489  0.394178  0.362002
# 12777      6  188.691537  0.219690  0.264479  0.379121  0.393543  0.369772
#
#        ...        41        42        43        44        45        46  \
# 0      ...  0.068604  0.073704  0.062183  0.063747  0.037182  0.038643
# 1      ...  0.068276  0.075037  0.059081  0.059467  0.035603  0.028895
# 2      ...  0.067477  0.080530  0.058376  0.057886  0.038616  0.026285
# 3      ...  0.068237  0.078969  0.056836  0.058719  0.035305  0.027785
# 4      ...  0.066844  0.081680  0.056108  0.058303  0.035014  0.029196
# ...    ...       ...       ...       ...       ...       ...       ...
# 12773  ...  0.073837  0.087236  0.060776  0.064276  0.052579  0.032439
# 12774  ...  0.075727  0.088738  0.059844  0.064279  0.051766  0.031167
# 12775  ...  0.077796  0.088561  0.060306  0.062437  0.051690  0.030675
# 12776  ...  0.075798  0.089035  0.059830  0.062551  0.051338  0.030363
# 12777  ...  0.074662  0.085817  0.061146  0.064594  0.051565  0.029521
#
#              47        48        49        50
# 0      0.022674  0.020251  0.015845  0.010102
# 1      0.023761  0.022457  0.013910  0.012265
# 2      0.026926  0.027973  0.015726  0.012053
# 3      0.024344  0.025738  0.015268  0.012773
# 4      0.023979  0.026220  0.015427  0.010830
# ...         ...       ...       ...       ...
# 12773  0.024865  0.017691  0.013245  0.011873
# 12774  0.024661  0.022322  0.012475  0.012487
# 12775  0.024565  0.017812  0.012371  0.011776
# 12776  0.024508  0.018358  0.012281  0.011888
# 12777  0.024372  0.017669  0.011507  0.011631
#
# [12778 rows x 54 columns]

# %%
from lib import join_and_order_dataset
data_fourier = join_and_order_dataset([dataset_on, dataset_off])
data_fourier
# Out:
#                                      name    location         device_id  \
# 0                 LATERNAWithTraffic2_000  Restaurant  029a77f196804217
# 1                 LATERNAWithTraffic2_001  Restaurant  029a77f196804217
# 2                 LATERNAWithTraffic2_002  Restaurant  029a77f196804217
# 3                 LATERNAWithTraffic2_003  Restaurant  029a77f196804217
# 4                 LATERNAWithTraffic2_004  Restaurant  029a77f196804217
# ...                                   ...         ...               ...
# 25737  spelaMilenkosRoomTrafficTable3_394   DormRoom3  e08d976ac75c011e
# 25738  spelaMilenkosRoomTrafficTable3_395   DormRoom3  e08d976ac75c011e
# 25739  spelaMilenkosRoomTrafficTable3_396   DormRoom3  e08d976ac75c011e
# 25740  spelaMilenkosRoomTrafficTable3_397   DormRoom3  e08d976ac75c011e
# 25741  spelaMilenkosRoomTrafficTable3_398   DormRoom3  e08d976ac75c011e
#
#        label           1         2         3         4         5         6  \
# 0          5  121.100560  6.312799  2.706040  2.555229  1.322195  1.853723
# 1          5  120.285898  7.234730  1.898696  2.998705  1.123582  1.578819
# 2          5  119.295022  7.926044  1.708508  2.626543  1.852330  0.606430
# 3          5  118.227067  8.240860  2.441177  1.532561  2.458682  1.457468
# 4          5  117.080056  8.154927  3.703195  0.942379  1.976951  2.021545
# ...      ...         ...       ...       ...       ...       ...       ...
# 25737      6  360.451236  0.409613  0.358197  0.415547  0.321003  0.415468
# 25738      6  360.443707  0.414223  0.354113  0.415970  0.310258  0.423525
# 25739      6  360.422738  0.436390  0.356295  0.419780  0.316700  0.421419
# 25740      6  360.426058  0.432698  0.354572  0.419575  0.306600  0.428967
# 25741      6  360.423268  0.433452  0.354840  0.417674  0.305939  0.431589
#
#        ...        41        42        43        44        45        46  \
# 0      ...  0.130141  0.148300  0.134433  0.125507  0.116128  0.132109
# 1      ...  0.151896  0.152574  0.148974  0.140587  0.140561  0.152706
# 2      ...  0.135930  0.121960  0.137269  0.130854  0.150641  0.121066
# 3      ...  0.153364  0.120233  0.157428  0.148213  0.154057  0.139036
# 4      ...  0.146717  0.103951  0.153434  0.158026  0.131962  0.149576
# ...    ...       ...       ...       ...       ...       ...       ...
# 25737  ...  0.076241  0.063529  0.052386  0.057157  0.032831  0.027539
# 25738  ...  0.076634  0.064143  0.053148  0.055866  0.035098  0.024716
# 25739  ...  0.077261  0.064220  0.055737  0.055496  0.037578  0.020855
# 25740  ...  0.076833  0.064219  0.054303  0.055642  0.032780  0.024571
# 25741  ...  0.075925  0.061766  0.058178  0.055933  0.039198  0.020754
#
#              47        48        49        50
# 0      0.115622  0.113349  0.105403  0.104297
# 1      0.134366  0.138558  0.135176  0.132545
# 2      0.129037  0.120758  0.124453  0.120136
# 3      0.139833  0.138810  0.130797  0.131372
# 4      0.130285  0.131980  0.132469  0.127399
# ...         ...       ...       ...       ...
# 25737  0.038029  0.020357  0.014417  0.007451
# 25738  0.038090  0.020986  0.012046  0.006563
# 25739  0.040300  0.021850  0.012729  0.007455
# 25740  0.037638  0.020527  0.014826  0.009319
# 25741  0.039036  0.019961  0.014284  0.008032
#
# [25742 rows x 54 columns]

# %%
import time
from lib import save_dataset
with open(f"{data_path}/metadata.json", 'r') as jsonfile:
    metadata = json.load(jsonfile)
    metadata['title'] = f"{version} fourier dataset big"
    metadata['description'] = 'Fourier dataset with windowed test cases from '+metadata['description']
    metadata['format'] = "processed"
    metadata['author'] = 'Mihael'
    metadata['version'] = version
    metadata['created'] = int(time.time())
save_dataset(data_fourier, dataset_target_path, dataset_name = 'fourier_window_big', metadata=metadata)
