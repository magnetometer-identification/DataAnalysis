# %%
import os
import pandas as pd
import glob
import json
version = "v5"
data_path = f"../data/interim/{version}"
dataset_target_path = "../data/processed"

# %%
from lib import read_dataset
data_on_raw, data_off_raw = read_dataset(data_path, classes = 2)
# Out:
# 0 milenkosRoomTrafficBed2
# 1 NadasKitchenWithTraffic
# 2 PiXmilenkosRoomTrafficTable2
# 3 NadasLivingRoomWithTrafficOrient2
# 4 milenkosRoomTrafficBed3
# 5 spelaMilenkosKitchenTrafficTable1
# 6 PiXmilenkosRoomTrafficTable6
# 7 milenkosRoomTrafficTable3
# 8 spelaMilenkosRoomTrafficTable3
# 9 spelaMilenkosRoomTrafficTable1
# 10 spelaMilenkosKitchenTrafficTable3
# 11 NadasKitchenWithTrafficOrient2
# 12 LATERNAWithTruffic
# 13 PiXmilenkosRoomTrafficTable3
# 14 PiXmilenkosRoomTrafficTable7
# 15 NadasBathroomWithTrafficOrient1
# 16 NadasLivingRoomWithTrafficOrient3
# 17 milenkosRoomTrafficTable2
# 18 spelaMilenkosKitchenTrafficTable4
# 19 milenkosRoomTrafficBed1
# 20 milenkosRoomWithTrafficDifferentOrentationWithPousesInRuns2
# 21 LATERNAresorantWithTrafic
# 22 milenkosRoomEithTrafficDifferentOrentationWithPousesInRuns3
# 23 spelaMilenkosRoomTrafficTable2
# 24 milenkosRoomTrafficTable
# 25 milenkosRoomWithTrafficDifferentOrentationWithPousesInRuns
# 26 MihasLivingRoom
# 27 NadasLivingRoomWithTraffic
# 28 NadasKitchenWithTrafficOrient3
# 29 PiXmilenkosRoomTrafficTable1
# 30 PiXmilenkosRoomTrafficTable4
# 31 PiXmilenkosRoomTrafficTable5
# 32 LATERNAWithTraffic2
# 33 spelaMilenkosKitchenTrafficTable2

# %%
from lib import add_intensity_to_dataset
add_intensity_to_dataset(data_on_raw)
add_intensity_to_dataset(data_off_raw)

# %%
from lib import normalize_dataset
columns = ['X_UnCal', 'Z_UnCal', 'Y_UnCal', 'Intensity']
normalize_dataset(data_on_raw, columns)
normalize_dataset(data_off_raw, columns)

# %%
list(data_on_raw.values())[0].describe()
# Out:
#         Unnamed: 0       X_UnCal       Y_UnCal       Z_UnCal   X_Bias  \
# count  7569.000000  7.569000e+03  7.569000e+03  7.569000e+03  7569.00
# mean   3784.000000 -3.454614e-15 -4.866500e-15 -5.872844e-15    39.48
# std    2185.126427  1.000000e+00  1.000000e+00  1.000000e+00     0.00
# min       0.000000 -3.987784e+00 -4.537622e+00 -3.406486e+00    39.48
# 25%    1892.000000 -6.871409e-01 -5.678371e-01 -7.185389e-01    39.48
# 50%    3784.000000  2.013960e-02  4.289935e-02 -4.655227e-02    39.48
# 75%    5676.000000  7.274201e-01  6.536358e-01  6.254344e-01    39.48
# max    7568.000000  3.674422e+00  3.503741e+00  6.113326e+00    39.48
#
#              Y_Bias        Z_Bias    time_UnCal  Accuracy     Intensity  \
# count  7.569000e+03  7.569000e+03  7.569000e+03    7569.0  7.569000e+03
# mean  -1.422000e+01  1.680000e+00  1.736390e+14       1.0 -1.830945e-14
# std    1.776474e-15  2.220593e-16  1.732111e+10       0.0  1.000000e+00
# min   -1.422000e+01  1.680000e+00  1.736090e+14       1.0 -3.792527e+00
# 25%   -1.422000e+01  1.680000e+00  1.736240e+14       1.0 -6.842399e-01
# 50%   -1.422000e+01  1.680000e+00  1.736390e+14       1.0  2.109208e-02
# 75%   -1.422000e+01  1.680000e+00  1.736540e+14       1.0  6.893905e-01
# max   -1.422000e+01  1.680000e+00  1.736690e+14       1.0  3.969053e+00
#
#        Bias_Intensity
# count    7.569000e+03
# mean     4.199644e+01
# std      7.105897e-15
# min      4.199644e+01
# 25%      4.199644e+01
# 50%      4.199644e+01
# 75%      4.199644e+01
# max      4.199644e+01

# %%
from collections import ChainMap
def subsamples(df: pd.DataFrame, name: str, window=2000, stride=10):
    return {f"{name}_{i:03d}": df[start:start+window] for i, start in enumerate(range(0,df.shape[0]-window, stride))}

data_on = dict(ChainMap(*[subsamples(df, name) for name,df in data_on_raw.items()]))
data_off = dict(ChainMap(*[subsamples(df, name) for name,df in data_off_raw.items()]))

# %%
len(data_on.keys())
# Out:
# 12778

# %%
data_on[list(data_on.keys())[0]]
# Out:
#       Unnamed: 0   X_UnCal   Y_UnCal   Z_UnCal     X_Bias  Y_Bias     Z_Bias  \
# 0              0  0.002362 -0.707033 -1.176172  56.879997   -10.8 -96.299995
# 1              1 -0.909320 -1.030137 -1.503631  56.879997   -10.8 -96.299995
# 2              2 -0.149585 -0.383924 -1.285337  56.879997   -10.8 -96.299995
# 3              3  0.458203  0.100735 -0.303014  56.879997   -10.8 -96.299995
# 4              4 -0.149585 -1.030137 -0.193867  56.879997   -10.8 -96.299995
# ...          ...       ...       ...       ...        ...     ...        ...
# 1995        1995 -1.365161 -1.191693 -1.612778  56.879997   -10.8 -96.299995
# 1996        1996 -0.301532 -2.484115 -0.739602  56.879997   -10.8 -96.299995
# 1997        1997  0.002362 -1.353243 -0.084720  56.879997   -10.8 -96.299995
# 1998        1998 -0.301532 -0.383924  0.897621  56.879997   -10.8 -96.299995
# 1999        1999  0.154309  0.423839  1.770779  56.879997   -10.8 -96.299995
#
#             time_UnCal  Accuracy         device_id  location  Intensity  \
# 0     3386562414059665         1  e08d976ac75c011e  Kitchen2   1.099888
# 1     3386562424057665         1  e08d976ac75c011e  Kitchen2   1.400776
# 2     3386562434056665         1  e08d976ac75c011e  Kitchen2   1.246283
# 3     3386562444055331         1  e08d976ac75c011e  Kitchen2   0.310133
# 4     3386562454054331         1  e08d976ac75c011e  Kitchen2   0.079964
# ...                ...       ...               ...       ...        ...
# 1995  3386582363453304         1  e08d976ac75c011e  Kitchen2   1.497030
# 1996  3386582373452070         1  e08d976ac75c011e  Kitchen2   0.470523
# 1997  3386582383450836         1  e08d976ac75c011e  Kitchen2  -0.066257
# 1998  3386582393449536         1  e08d976ac75c011e  Kitchen2  -0.942213
# 1999  3386582403448302         1  e08d976ac75c011e  Kitchen2  -1.731029
#
#       Bias_Intensity
# 0         112.363976
# 1         112.363976
# 2         112.363976
# 3         112.363976
# 4         112.363976
# ...              ...
# 1995      112.363976
# 1996      112.363976
# 1997      112.363976
# 1998      112.363976
# 1999      112.363976
#
# [2000 rows x 13 columns]

# %%
from lib import spectral_dataset
dataset_on_intensity = spectral_dataset(data_on, 6, vec_len=50, column='Intensity', experiment_duration=10)
dataset_on_X = spectral_dataset(data_on, 6, vec_len=50, column='X_UnCal', experiment_duration=10)
dataset_on_Y = spectral_dataset(data_on, 6, vec_len=50, column='Y_UnCal', experiment_duration=10)
dataset_on_Z = spectral_dataset(data_on, 6, vec_len=50, column='Z_UnCal', experiment_duration=10)
dataset_off_intensity = spectral_dataset(data_off, 5, vec_len=50, column='Intensity', experiment_duration=10)
dataset_off_X = spectral_dataset(data_off, 5, vec_len=50, column='X_UnCal', experiment_duration=10)
dataset_off_Y = spectral_dataset(data_off, 5, vec_len=50, column='Y_UnCal', experiment_duration=10)
dataset_off_Z = spectral_dataset(data_off, 5, vec_len=50, column='Z_UnCal', experiment_duration=10)

# %%
dataset_on_intensity.rename(lambda x: f"intensity_{x}", axis='columns', inplace=True)
dataset_on_X.rename(lambda x: f"X_{x}", axis='columns', inplace=True)
dataset_on_Y.rename(lambda x: f"Y_{x}", axis='columns', inplace=True)
dataset_on_Z.rename(lambda x: f"Z_{x}", axis='columns', inplace=True)

# %%
dataset_off_intensity.rename(lambda x: f"intensity_{x}", axis='columns', inplace=True)
dataset_off_X.rename(lambda x: f"X_{x}", axis='columns', inplace=True)
dataset_off_Y.rename(lambda x: f"Y_{x}", axis='columns', inplace=True)
dataset_off_Z.rename(lambda x: f"Z_{x}", axis='columns', inplace=True)

# %%
dataset_on = pd.concat([dataset_on_intensity, dataset_on_X.iloc[:,4:], dataset_on_Y.iloc[:,4:], dataset_on_Z.iloc[:,4:]], axis=1)
dataset_on = dataset_on.rename(columns={"intensity_name": "name", "intensity_location": "location", "intensity_device_id": "device_id", "intensity_label": "label"})

# %%
dataset_off = pd.concat([dataset_off_intensity, dataset_off_X.iloc[:,4:], dataset_off_Y.iloc[:,4:], dataset_off_Z.iloc[:,4:]], axis=1)
dataset_off = dataset_off.rename(columns={"intensity_name": "name", "intensity_location": "location", "intensity_device_id": "device_id", "intensity_label": "label"})

# %%
dataset_off
# Out:
#                                         name   location         device_id  \
# 0      spelaMilenkosKitchenTrafficTable2_000   Kitchen2  e08d976ac75c011e
# 1      spelaMilenkosKitchenTrafficTable2_001   Kitchen2  e08d976ac75c011e
# 2      spelaMilenkosKitchenTrafficTable2_002   Kitchen2  e08d976ac75c011e
# 3      spelaMilenkosKitchenTrafficTable2_003   Kitchen2  e08d976ac75c011e
# 4      spelaMilenkosKitchenTrafficTable2_004   Kitchen2  e08d976ac75c011e
# ...                                      ...        ...               ...
# 12959            milenkosRoomTrafficBed2_554  DormRoom1  029a77f196804217
# 12960            milenkosRoomTrafficBed2_555  DormRoom1  029a77f196804217
# 12961            milenkosRoomTrafficBed2_556  DormRoom1  029a77f196804217
# 12962            milenkosRoomTrafficBed2_557  DormRoom1  029a77f196804217
# 12963            milenkosRoomTrafficBed2_558  DormRoom1  029a77f196804217
#
#        label  intensity_1  intensity_2  intensity_3  intensity_4  intensity_5  \
# 0          5     0.819202     0.849604     0.534788     0.830704     0.749828
# 1          5     0.841961     0.821032     0.552060     0.832475     0.781532
# 2          5     0.843107     0.818933     0.557212     0.835073     0.795343
# 3          5     0.847196     0.813851     0.562771     0.836339     0.794178
# 4          5     0.869629     0.822711     0.524929     0.818735     0.780464
# ...      ...          ...          ...          ...          ...          ...
# 12959      5     1.831288     0.804523     0.753059     0.867424     0.762781
# 12960      5     1.822463     0.805490     0.744518     0.866117     0.769031
# 12961      5     1.802239     0.831621     0.753819     0.874488     0.767854
# 12962      5     1.819469     0.804777     0.737729     0.874205     0.776408
# 12963      5     1.829955     0.791790     0.729709     0.883581     0.778682
#
#        intensity_6  ...      Z_41      Z_42      Z_43      Z_44      Z_45  \
# 0         0.589579  ...  0.196765  0.168867  0.143866  0.108885  0.108539
# 1         0.576387  ...  0.199244  0.164731  0.144656  0.113603  0.112556
# 2         0.572083  ...  0.198313  0.171209  0.142245  0.108900  0.109867
# 3         0.576958  ...  0.196555  0.162283  0.138215  0.105936  0.110904
# 4         0.564533  ...  0.205440  0.175599  0.137099  0.106649  0.108224
# ...            ...  ...       ...       ...       ...       ...       ...
# 12959     0.876664  ...  0.120864  0.169393  0.088121  0.117655  0.095615
# 12960     0.880556  ...  0.118615  0.161545  0.094039  0.115256  0.094341
# 12961     0.879162  ...  0.120619  0.166495  0.088073  0.115694  0.098940
# 12962     0.885662  ...  0.128857  0.162970  0.099075  0.115873  0.098597
# 12963     0.885930  ...  0.126027  0.163836  0.097383  0.116372  0.100900
#
#            Z_46      Z_47      Z_48      Z_49      Z_50
# 0      0.073412  0.078649  0.043243  0.038611  0.018213
# 1      0.071462  0.075601  0.045834  0.039475  0.024256
# 2      0.072133  0.077207  0.044022  0.039607  0.017866
# 3      0.079045  0.092245  0.050019  0.037243  0.025008
# 4      0.073719  0.079826  0.042603  0.036167  0.013526
# ...         ...       ...       ...       ...       ...
# 12959  0.080084  0.061017  0.041021  0.024989  0.017522
# 12960  0.077880  0.067585  0.041604  0.026077  0.022889
# 12961  0.077732  0.067900  0.041518  0.025559  0.021167
# 12962  0.082344  0.069601  0.045586  0.032953  0.016503
# 12963  0.087205  0.070915  0.048682  0.037237  0.026072
#
# [12964 rows x 204 columns]

# %%
from lib import join_and_order_dataset
data_fourier = join_and_order_dataset([dataset_on, dataset_off])
data_fourier
# Out:
#                                      name    location         device_id  \
# 0                 LATERNAWithTraffic2_000  Restaurant  029a77f196804217
# 1                 LATERNAWithTraffic2_001  Restaurant  029a77f196804217
# 2                 LATERNAWithTraffic2_002  Restaurant  029a77f196804217
# 3                 LATERNAWithTraffic2_003  Restaurant  029a77f196804217
# 4                 LATERNAWithTraffic2_004  Restaurant  029a77f196804217
# ...                                   ...         ...               ...
# 25737  spelaMilenkosRoomTrafficTable3_394   DormRoom3  e08d976ac75c011e
# 25738  spelaMilenkosRoomTrafficTable3_395   DormRoom3  e08d976ac75c011e
# 25739  spelaMilenkosRoomTrafficTable3_396   DormRoom3  e08d976ac75c011e
# 25740  spelaMilenkosRoomTrafficTable3_397   DormRoom3  e08d976ac75c011e
# 25741  spelaMilenkosRoomTrafficTable3_398   DormRoom3  e08d976ac75c011e
#
#        label  intensity_1  intensity_2  intensity_3  intensity_4  intensity_5  \
# 0          5     7.470365     2.983096     1.278732     1.207467     0.624800
# 1          5     6.932167     3.418753     0.897224     1.417030     0.530946
# 2          5     6.296129     3.745431     0.807351     1.241166     0.875314
# 3          5     5.625500     3.894197     1.153572     0.724208     1.161844
# 4          5     4.917718     3.853589     1.749935     0.445318     0.934203
# ...      ...          ...          ...          ...          ...          ...
# 25737      6     1.448107     0.822474     0.719234     0.834389     0.644552
# 25738      6     1.442828     0.831731     0.711035     0.835240     0.622976
# 25739      6     1.433643     0.876241     0.715415     0.842888     0.635912
# 25740      6     1.434282     0.868828     0.711956     0.842478     0.615631
# 25741      6     1.434446     0.870341     0.712494     0.838660     0.614304
#
#        intensity_6  ...      Z_41      Z_42      Z_43      Z_44      Z_45  \
# 0         0.875972  ...  0.136108  0.096289  0.085358  0.086715  0.093671
# 1         0.746067  ...  0.120129  0.090735  0.084263  0.064035  0.063160
# 2         0.286567  ...  0.137018  0.119407  0.102829  0.082438  0.069137
# 3         0.688723  ...  0.121788  0.117716  0.086604  0.075138  0.064997
# 4         0.955276  ...  0.129110  0.131515  0.088830  0.082020  0.089999
# ...            ...  ...       ...       ...       ...       ...       ...
# 25737     0.834230  ...  0.151905  0.124693  0.104593  0.116759  0.068790
# 25738     0.850409  ...  0.152489  0.126185  0.105716  0.113783  0.072710
# 25739     0.846181  ...  0.153551  0.125487  0.110652  0.112698  0.077612
# 25740     0.861336  ...  0.152873  0.125867  0.107482  0.113699  0.067130
# 25741     0.866601  ...  0.151648  0.121067  0.114960  0.113464  0.079779
#
#            Z_46      Z_47      Z_48      Z_49      Z_50
# 0      0.063959  0.069161  0.066806  0.077327  0.070788
# 1      0.081285  0.053997  0.051931  0.044170  0.045198
# 2      0.084191  0.069214  0.072006  0.067250  0.063130
# 3      0.057610  0.057262  0.053393  0.058720  0.054178
# 4      0.069270  0.069778  0.064942  0.053228  0.055580
# ...         ...       ...       ...       ...       ...
# 25737  0.055596  0.074826  0.040742  0.029499  0.015188
# 25738  0.048439  0.074840  0.042487  0.023915  0.012805
# 25739  0.040978  0.078803  0.043751  0.024963  0.014371
# 25740  0.049002  0.073902  0.041623  0.030393  0.019340
# 25741  0.041268  0.076260  0.040152  0.028357  0.015549
#
# [25742 rows x 204 columns]

# %%
import time
from lib import save_dataset
with open(f"{data_path}/metadata.json", 'r') as jsonfile:
    metadata = json.load(jsonfile)
    metadata['title'] = f"{version} fourier dataset normalized"
    metadata['description'] = 'Fourier dataset with normalized and windowed test cases from '+metadata['description']
    metadata['format'] = "processed"
    metadata['author'] = 'Mihael'
    metadata['version'] = version
    metadata['created'] = int(time.time())
save_dataset(data_fourier, dataset_target_path, dataset_name = 'fourier_normalized_int_XYZ', metadata=metadata)
