# %%
import json
import pandas as pd
import glob
data_path = "../data/raw"

# %%
for file_name in glob.glob(f"{data_path}/*"):
    print(file_name)
# Out:
# ../data/raw/Data__2_proba13.json
# ../data/raw/Data__4_test.json
# ../data/raw/Data__5_proba3.json
# ../data/raw/Data__2_proba8.json
# ../data/raw/Data__5_zzz.json
# ../data/raw/Data__6_mmm.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_3_4.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_4_jjj.json
# ../data/raw/Data__4_proba.json
# ../data/raw/Data__4_zzz.json
# ../data/raw/Data__6_proba14.json
# ../data/raw/Data__5_offline-test.json
# ../data/raw/Data__5_proba10.json
# ../data/raw/Data__6_offline-test.json
# ../data/raw/Data__4_proba6.json
# ../data/raw/Data__4_mmm.json
# ../data/raw/Data__2_proba12.json
# ../data/raw/Data__5_proba12.json
# ../data/raw/Data__2_proba11.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_2_4.json
# ../data/raw/Data__2_mmm.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_3_neja.json
# ../data/raw/Data__5_proba13.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_1_4.json
# ../data/raw/Data__6_proba15.json
# ../data/raw/Data__1_proba.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_3_3.json
# ../data/raw/Data__5_proba8.json
# ../data/raw/Data__1_test.json
# ../data/raw/Data__2_proba.json
# ../data/raw/Data__6_poiuy.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_2_3.json
# ../data/raw/Data__1_proba9.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_3_jjj.json
# ../data/raw/Data__2_proba10.json
# ../data/raw/Data__5_mmm.json
# ../data/raw/Data__1_zzz.json
# ../data/raw/Data__4_proba10.json
# ../data/raw/Data__3_proba10.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_1_3.json
# ../data/raw/Data__3_proba15.json
# ../data/raw/Data__5_proba.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_1_jjj.json
# ../data/raw/Data__2_proba14.json
# ../data/raw/Data__1_proba13.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_6_jjj.json
# ../data/raw/Data__3_test.json
# ../data/raw/Data__3_offline-test.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_2_jjj.json
# ../data/raw/Data__1_proba14.json
# ../data/raw/Data__3_proba13.json
# ../data/raw/Data__5_proba14.json
# ../data/raw/Data__2_offline-test.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_4_4.json
# ../data/raw/Data__3_zzz.json
# ../data/raw/Data__6_proba.json
# ../data/raw/Data__3_proba14.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_5_jjj.json
# ../data/raw/Data__5_proba9.json
# ../data/raw/Data__6_proba13.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_5_4.json
# ../data/raw/Data__5_test.json
# ../data/raw/Data__2_proba6.json
# ../data/raw/Data__1_proba3.json
# ../data/raw/Data__2_test.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_2_pop.json
# ../data/raw/Data__3_proba9.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_6_3.json
# ../data/raw/Data__2_proba3.json
# ../data/raw/Data__5_poiuy.json
# ../data/raw/Data__4_proba13.json
# ../data/raw/Data__4_proba8.json
# ../data/raw/Data__4_proba3.json
# ../data/raw/Data__5_proba6.json
# ../data/raw/Data__3_poiuy.json
# ../data/raw/Data__1_proba15.json
# ../data/raw/Data__1_proba10.json
# ../data/raw/Data__3_proba3.json
# ../data/raw/Data__4_poiuy.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_3_mihail.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_6_4.json
# ../data/raw/Data__1_mmm.json
# ../data/raw/Data__2_poiuy.json
# ../data/raw/Data__5_proba15.json
# ../data/raw/Data__4_proba15.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_5_uuu.json
# ../data/raw/Data__4_proba14.json
# ../data/raw/Data__2_proba15.json
# ../data/raw/Data__1_proba6.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_1_moron.json
# ../data/raw/Data__4_offline-test.json
# ../data/raw/Data__2_proba9.json
# ../data/raw/Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_5_3.json
# ../data/raw/Data__1_poiuy.json
# ../data/raw/Data__3_proba6.json
# ../data/raw/Data__4_proba9.json
# ../data/raw/Data__3_mmm.json
# ../data/raw/Data__3_proba.json
# ../data/raw/Data__6_proba10.json

# %%
file = "Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_1_3.json"

# file = "Data_808ab033-5ecb-464e-9468-f0dd985a7fd0_3_neja.json"
data = json.load(open(f"{data_path}/{file}", "r"))[0]

# %% [markdown]
# # generating dataset
# first_timestamp_miliseconds = data["time_AWARE"][0]
# last_timestamp_miliseconds = data["time_AWARE"][-1]
# time_diff_miliseconds =  last_timestamp_miliseconds - first_timestamp_miliseconds
# n_uncalibrated_samples = len(data["X_UnCal"])
# diff = time_diff_miliseconds / (n_uncalibrated_samples -1)
# data["time_uncalibrated"] = [first_timestamp_miliseconds + i * diff for i in range(n_uncalibrated_samples)]
#
# df_AWARE = pd.DataFrame({k: data[k] for k in ["X_AWARE", "Y_AWARE", "Z_AWARE", "time_AWARE"]})
# df_uncalibrated = pd.DataFrame({k: data[k] for k in ["X_UnCal", "Y_UnCal", "Z_UnCal", "X_Bias", "Y_Bias", "Z_Bias", "time_uncalibrated"]})
#
# # some metadata
# df_aware_features = list(df_AWARE.columns)
# df_uncalibrated_features = list(df_uncalibrated.columns)
# device_id = data['DEVICE_ID_AWARE']
# stage = data["stage"]
# duration_seconds = time_diff_miliseconds / 1000
# aware_sample_rate = df_AWARE.size / duration_seconds
# uncalibrated_sample_rate = df_uncalibrated.size / duration_seconds
# print(f"{device_id = }")
# print(f"{stage = }")
# print(f"{duration_seconds =}s")
# print(f"{aware_sample_rate = : .2f} Hz")
# print(f"{df_aware_features = }")
# print(f"{uncalibrated_sample_rate = :.2f} Hz")
# print(f"{df_uncalibrated_features = }")
