# %%
import os
import pandas as pd
import glob
import json
version = "v4"
data_path = f"../data/interim/{version}"
dataset_target_path = "../data/processed"

# %%
from lib import read_dataset
data_on_raw, data_off_raw = read_dataset(data_path, classes = 2)
# Out:
# 0 milenkosKitchenNotNearDevicesWithTraffic
# 1 milenkosKitchenNotNearDevicesWithTraffic1
# 2 milenkoParkWithTraffic1
# 3 milenkosRoomNearDevicesWithTraffic
# 4 milenkosRoomNearDevicesWithTraffic1
# 5 milenkoParkWithTraffic

# %%
from lib import add_intensity_to_dataset
add_intensity_to_dataset(data_on_raw)
add_intensity_to_dataset(data_off_raw)

# %%
from collections import ChainMap
def subsamples(df: pd.DataFrame, name: str, window=2000, stride=10):
    return {f"{name}_{i:03d}": df[start:start+window] for i, start in enumerate(range(0,df.shape[0]-window, stride))}

data_on = dict(ChainMap(*[subsamples(df, name) for name,df in data_on_raw.items()]))
data_off = dict(ChainMap(*[subsamples(df, name) for name,df in data_off_raw.items()]))

# %%
len(data_on.keys())
# Out:
# 2405

# %%
data_on[list(data_on.keys())[0]]
# Out:
#       Unnamed: 0  X_UnCal    Y_UnCal    Z_UnCal     X_Bias     Y_Bias  \
# 0              0 -36.7342  58.035400 -77.970200 -17.414808  48.837105
# 1              1 -38.9302  58.145200 -81.239800 -17.414808  48.837105
# 2              2 -41.4556  58.218400 -82.105995 -17.414808  48.837105
# 3              3 -42.7854  56.095600 -80.788400 -17.414808  48.837105
# 4              4 -42.6634  56.327400 -79.727000 -17.414808  48.837105
# ...          ...      ...        ...        ...        ...        ...
# 1995        1995 -33.8550  58.230600 -76.420800 -17.414808  48.837105
# 1996        1996 -33.5866  58.267200 -76.140200 -17.414808  48.837105
# 1997        1997 -33.3914  58.425800 -76.664795 -17.414808  48.837105
# 1998        1998 -33.5988  58.523400 -76.750200 -17.414808  48.837105
# 1999        1999 -33.9526  58.315998 -77.653000 -17.414808  48.837105
#
#         Z_Bias    time_UnCal  Accuracy   Intensity  Bias_Intensity
# 0    -32.69565  948131391278         1  103.907946       61.297177
# 1    -32.69565  948141390545         1  107.220939       61.297177
# 2    -32.69565  948151378094         1  108.854689       61.297177
# 3    -32.69565  948161391033         1  107.257039       61.297177
# 4    -32.69565  948171391033         1  106.533263       61.297177
# ...        ...           ...       ...         ...             ...
# 1995 -32.69565  968081390789         1  101.868064       61.297177
# 1996 -32.69565  968091391033         1  101.589647       61.297177
# 1997 -32.69565  968101378094         1  102.010051       61.297177
# 1998 -32.69565  968111391033         1  102.198145       61.297177
# 1999 -32.69565  968121385906         1  102.876251       61.297177
#
# [2000 rows x 11 columns]

# %%
from lib import spectral_dataset
dataset_on = spectral_dataset(data_on, 6, vec_len=50, column='Intensity', experiment_duration=10)
dataset_off = spectral_dataset(data_off, 5, vec_len=50, column='Intensity', experiment_duration=10)

# %%
dataset_on#.iloc[0,:].to_list()
# Out:
#                                               Name  Label           1  \
# 0                       milenkoParkWithTraffic_000      6  209.823637
# 1                       milenkoParkWithTraffic_001      6  209.781112
# 2                       milenkoParkWithTraffic_002      6  209.777792
# 3                       milenkoParkWithTraffic_003      6  209.784275
# 4                       milenkoParkWithTraffic_004      6  209.801560
# ...                                            ...    ...         ...
# 2400  milenkosKitchenNotNearDevicesWithTraffic_395      6  166.244795
# 2401  milenkosKitchenNotNearDevicesWithTraffic_396      6  166.245118
# 2402  milenkosKitchenNotNearDevicesWithTraffic_397      6  166.246727
# 2403  milenkosKitchenNotNearDevicesWithTraffic_398      6  166.246836
# 2404  milenkosKitchenNotNearDevicesWithTraffic_399      6  166.247471
#
#              2         3         4         5         6         7         8  \
# 0     3.175178  2.229413  1.230265  2.059367  1.049306  1.120012  0.551426
# 1     3.168640  2.242565  1.277486  1.979290  1.090832  1.074244  0.616023
# 2     3.158185  2.209576  1.303754  1.992657  1.092777  1.066338  0.560022
# 3     3.139415  2.150105  1.301560  2.027034  1.054355  1.098607  0.604741
# 4     3.118269  2.114001  1.274040  2.031570  1.058257  1.070821  0.619792
# ...        ...       ...       ...       ...       ...       ...       ...
# 2400  1.198609  0.975360  1.366340  0.931904  0.575495  0.513259  0.548664
# 2401  1.200070  0.977488  1.365869  0.931391  0.576920  0.513105  0.546877
# 2402  1.170659  0.907269  1.396869  0.857189  0.625361  0.479583  0.448152
# 2403  1.170810  0.907942  1.396020  0.857749  0.622922  0.479464  0.448126
# 2404  1.171194  0.910387  1.393402  0.862178  0.616087  0.478212  0.447128
#
#       ...        41        42        43        44        45        46  \
# 0     ...  0.253911  0.465845  0.273631  0.337214  0.378180  0.264307
# 1     ...  0.262165  0.453841  0.281837  0.341968  0.375076  0.272332
# 2     ...  0.259552  0.456945  0.281303  0.338994  0.375113  0.269770
# 3     ...  0.256193  0.463085  0.276811  0.335160  0.381940  0.257803
# 4     ...  0.266508  0.449933  0.285837  0.340735  0.380118  0.264150
# ...   ...       ...       ...       ...       ...       ...       ...
# 2400  ...  0.249676  0.204745  0.266388  0.291860  0.303853  0.223725
# 2401  ...  0.246213  0.199417  0.261906  0.289392  0.306493  0.226383
# 2402  ...  0.239634  0.191269  0.280731  0.293709  0.311881  0.218187
# 2403  ...  0.239423  0.199645  0.285946  0.295166  0.307841  0.218554
# 2404  ...  0.242150  0.206625  0.266954  0.285920  0.315596  0.221971
#
#             47        48        49        50
# 0     0.327211  0.383311  0.501575  0.268972
# 1     0.333915  0.380834  0.496013  0.294400
# 2     0.331387  0.386997  0.495056  0.297902
# 3     0.326465  0.382527  0.500696  0.285677
# 4     0.326078  0.387558  0.505013  0.265562
# ...        ...       ...       ...       ...
# 2400  0.277276  0.328032  0.297361  0.299029
# 2401  0.284382  0.330371  0.298636  0.303166
# 2402  0.271945  0.331328  0.297062  0.286577
# 2403  0.278398  0.333995  0.298657  0.280983
# 2404  0.273120  0.329286  0.295519  0.295066
#
# [2405 rows x 52 columns]

# %%
from lib import join_and_order_dataset
data_fourier = join_and_order_dataset([dataset_on, dataset_off])
data_fourier
# Out:
#                                         Name  Label           1         2  \
# 0               milenkoParkWithTraffic1 _000      5  207.172153  0.468144
# 1               milenkoParkWithTraffic1 _001      5  206.970217  0.388701
# 2               milenkoParkWithTraffic1 _002      5  206.942104  0.383917
# 3               milenkoParkWithTraffic1 _003      5  206.885002  0.369968
# 4               milenkoParkWithTraffic1 _004      5  206.884916  0.369640
# ...                                      ...    ...         ...       ...
# 4800  milenkosRoomNearDevicesWithTraffic_396      6  188.719426  0.320276
# 4801  milenkosRoomNearDevicesWithTraffic_397      6  188.714416  0.322622
# 4802  milenkosRoomNearDevicesWithTraffic_398      6  188.709728  0.329794
# 4803  milenkosRoomNearDevicesWithTraffic_399      6  188.724243  0.307849
# 4804  milenkosRoomNearDevicesWithTraffic_400      6  188.740944  0.291271
#
#              3         4         5         6         7         8  ...  \
# 0     0.341186  0.421061  0.387978  0.350247  0.357487  0.389721  ...
# 1     0.312928  0.408111  0.335855  0.213800  0.237148  0.318643  ...
# 2     0.314391  0.411951  0.333932  0.217265  0.229431  0.332336  ...
# 3     0.297788  0.384554  0.327792  0.244281  0.259171  0.308525  ...
# 4     0.297073  0.384702  0.328044  0.241436  0.256669  0.309401  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 4800  0.397127  0.307688  0.259728  0.321650  0.304093  0.248510  ...
# 4801  0.394177  0.306637  0.263913  0.334070  0.302969  0.243131  ...
# 4802  0.398164  0.311385  0.258254  0.322756  0.302789  0.247962  ...
# 4803  0.384704  0.302495  0.265871  0.327138  0.311159  0.255066  ...
# 4804  0.376352  0.307071  0.261480  0.311581  0.307189  0.255677  ...
#
#             41        42        43        44        45        46        47  \
# 0     0.265508  0.204846  0.201943  0.314249  0.212037  0.196977  0.199215
# 1     0.263252  0.206338  0.202653  0.313383  0.211475  0.197184  0.200885
# 2     0.266366  0.213860  0.206609  0.312029  0.210893  0.205998  0.194127
# 3     0.245821  0.204013  0.198563  0.314205  0.214127  0.229022  0.194430
# 4     0.230323  0.202929  0.202852  0.315391  0.221627  0.253896  0.189422
# ...        ...       ...       ...       ...       ...       ...       ...
# 4800  0.271833  0.239965  0.193979  0.192186  0.169587  0.155362  0.288890
# 4801  0.275423  0.238673  0.191375  0.193144  0.183926  0.155927  0.289603
# 4802  0.274945  0.239913  0.191375  0.191180  0.178905  0.155194  0.288641
# 4803  0.300085  0.263497  0.186466  0.179305  0.149089  0.158117  0.293479
# 4804  0.283654  0.247923  0.180429  0.180261  0.154426  0.166801  0.305135
#
#             48        49        50
# 0     0.301456  0.207358  0.240142
# 1     0.302107  0.211149  0.237258
# 2     0.299422  0.199722  0.233439
# 3     0.301596  0.198571  0.210282
# 4     0.291817  0.215148  0.204918
# ...        ...       ...       ...
# 4800  0.214403  0.170422  0.198570
# 4801  0.224957  0.183206  0.195439
# 4802  0.216956  0.170438  0.199910
# 4803  0.216194  0.183489  0.198911
# 4804  0.218166  0.208505  0.202023
#
# [4805 rows x 52 columns]

# %%
import time
from lib import save_dataset
with open(f"{data_path}/metadata.json", 'r') as jsonfile:
    metadata = json.load(jsonfile)
    metadata['title'] = f"{version} fourier dataset big"
    metadata['description'] = 'Fourier dataset with windowed test cases from '+metadata['description']
    metadata['format'] = "processed"
    metadata['author'] = 'Mihael'
    metadata['version'] = version
    metadata['created'] = int(time.time())
save_dataset(data_fourier, dataset_target_path, dataset_name = 'fourier_window_big', metadata=metadata)
