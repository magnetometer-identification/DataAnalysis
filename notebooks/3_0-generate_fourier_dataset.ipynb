# %%
import os
import pandas as pd
import glob
import json
version = "v4"
data_path = f"../data/interim/{version}"
dataset_target_path = "../data/processed"

# %%
from lib import read_dataset
data_on_raw, data_off_raw = read_dataset(data_path, classes = 2)
# Out:
# 0 milenkosKitchenNotNearDevicesWithTraffic
# 1 milenkosKitchenNotNearDevicesWithTraffic1
# 2 milenkoParkWithTraffic1
# 3 milenkosRoomNearDevicesWithTraffic
# 4 milenkosRoomNearDevicesWithTraffic1
# 5 milenkoParkWithTraffic

# %%
from lib import add_intensity_to_dataset
add_intensity_to_dataset(data_on_raw)
add_intensity_to_dataset(data_off_raw)

# %%
from collections import ChainMap
def subsamples(df: pd.DataFrame, name: str, window=1000, stride=500):
    return {f"{name}_{i}": df[start:start+window] for i, start in enumerate(range(0,df.shape[0]-window, stride))}

data_on = dict(ChainMap(*[subsamples(df, name) for name,df in data_on_raw.items()]))
data_off = dict(ChainMap(*[subsamples(df, name) for name,df in data_off_raw.items()]))

# %%
data_on[list(data_on.keys())[0]]
# Out:
#      Unnamed: 0    X_UnCal  Y_UnCal    Z_UnCal     X_Bias     Y_Bias  \
# 0             0 -36.734200  58.0354 -77.970200 -17.414808  48.837105
# 1             1 -38.930200  58.1452 -81.239800 -17.414808  48.837105
# 2             2 -41.455600  58.2184 -82.105995 -17.414808  48.837105
# 3             3 -42.785400  56.0956 -80.788400 -17.414808  48.837105
# 4             4 -42.663400  56.3274 -79.727000 -17.414808  48.837105
# ..          ...        ...      ...        ...        ...        ...
# 995         995 -33.537800  58.3526 -75.603400 -17.414808  48.837105
# 996         996 -32.415398  59.0724 -76.140200 -17.414808  48.837105
# 997         997 -33.806200  58.1208 -76.274400 -17.414808  48.837105
# 998         998 -32.464200  58.6698 -75.957200 -17.414808  48.837105
# 999         999 -32.427600  59.3652 -75.237400 -17.414808  48.837105
#
#        Z_Bias    time_UnCal  Accuracy   Intensity  Bias_Intensity
# 0   -32.69565  948131391278         1  103.907946       61.297177
# 1   -32.69565  948141390545         1  107.220939       61.297177
# 2   -32.69565  948151378094         1  108.854689       61.297177
# 3   -32.69565  948161391033         1  107.257039       61.297177
# 4   -32.69565  948171391033         1  106.533263       61.297177
# ..        ...           ...       ...         ...             ...
# 995 -32.69565  958081391033         1  101.220966       61.297177
# 996 -32.69565  958091391033         1  101.674168       61.297177
# 997 -32.69565  958101391033         1  101.679254       61.297177
# 998 -32.69565  958111391033         1  101.319129       61.297177
# 999 -32.69565  958121391033         1  101.175306       61.297177
#
# [1000 rows x 11 columns]

# %%
from lib import spectral_dataset
dataset_on = spectral_dataset(data_on, 6, vec_len=50, column='Intensity', experiment_duration=10)
dataset_off = spectral_dataset(data_off, 5, vec_len=50, column='Intensity', experiment_duration=10)

# %%
dataset_on
# Out:
#                                           Name  Label           1         2  \
# 0                     milenkoParkWithTraffic_0      6  213.547204  3.373715
# 1                     milenkoParkWithTraffic_1      6  204.790685  0.956746
# 2                     milenkoParkWithTraffic_2      6  204.968150  1.095068
# 3                     milenkoParkWithTraffic_3      6  204.723923  0.800941
# 4                     milenkoParkWithTraffic_4      6  204.076315  0.565776
# ..                                         ...    ...         ...       ...
# 60  milenkosKitchenNotNearDevicesWithTraffic_5      6  165.021181  0.692016
# 61  milenkosKitchenNotNearDevicesWithTraffic_6      6  170.856096  2.970649
# 62  milenkosKitchenNotNearDevicesWithTraffic_7      6  170.732101  2.990963
# 63  milenkosKitchenNotNearDevicesWithTraffic_8      6  167.372258  2.205086
# 64  milenkosKitchenNotNearDevicesWithTraffic_9      6  167.373421  2.187688
#
#            3         4         5         6         7         8  ...        41  \
# 0   2.972668  1.552570  1.183755  1.165933  0.968522  1.146294  ...  0.428935
# 1   0.630523  0.527639  0.415008  0.480141  0.476522  0.509971  ...  0.279435
# 2   0.810644  0.737867  0.559686  0.605325  0.539708  0.447025  ...  0.182574
# 3   0.740934  0.849141  0.623203  0.463683  0.519209  0.319277  ...  0.114600
# 4   0.433475  0.652202  0.516659  0.292303  0.411094  0.304575  ...  0.208152
# ..       ...       ...       ...       ...       ...       ...  ...       ...
# 60  0.526594  0.401482  0.387547  0.482390  0.404436  0.366592  ...  0.323537
# 61  1.965695  1.066305  1.044956  1.071107  0.890409  0.915735  ...  0.298798
# 62  2.136208  1.310869  1.108617  1.111383  0.879273  0.928352  ...  0.341961
# 63  1.291570  0.667070  0.622330  0.805041  0.476315  0.468913  ...  0.404808
# 64  1.275758  0.717083  0.496699  0.793050  0.427987  0.376954  ...  0.393141
#
#           42        43        44        45        46        47        48  \
# 0   0.662504  0.599305  0.480306  0.316803  0.438741  0.518917  0.512946
# 1   0.389926  0.205318  0.287658  0.227519  0.298395  0.258926  0.249867
# 2   0.239533  0.250281  0.304495  0.245843  0.263252  0.251199  0.272950
# 3   0.207457  0.318966  0.226293  0.289519  0.310408  0.248082  0.280247
# 4   0.244241  0.267840  0.239516  0.260228  0.238217  0.310183  0.266784
# ..       ...       ...       ...       ...       ...       ...       ...
# 60  0.421287  0.250462  0.316688  0.338395  0.267655  0.268748  0.356278
# 61  0.444823  0.300230  0.393842  0.542134  0.399820  0.445224  0.442349
# 62  0.442396  0.297189  0.397096  0.582628  0.491837  0.429289  0.426562
# 63  0.471325  0.235326  0.352179  0.373710  0.332791  0.424712  0.288562
# 64  0.291398  0.328914  0.321120  0.341152  0.359776  0.479669  0.346466
#
#           49        50
# 0   0.450229  0.361353
# 1   0.323095  0.289228
# 2   0.327179  0.265641
# 3   0.270007  0.258846
# 4   0.297368  0.302228
# ..       ...       ...
# 60  0.284843  0.270116
# 61  0.262643  0.272660
# 62  0.300483  0.280589
# 63  0.310312  0.423832
# 64  0.302205  0.433814
#
# [65 rows x 52 columns]

# %%
from lib import join_and_order_dataset
data_fourier = join_and_order_dataset([dataset_on, dataset_off])
data_fourier
# Out:
#                                      Name  Label           1         2  \
# 0              milenkoParkWithTraffic1 _0      5  207.513316  0.670235
# 1              milenkoParkWithTraffic1 _1      5  206.820374  0.540585
# 2              milenkoParkWithTraffic1 _2      5  206.958134  0.535590
# 3              milenkoParkWithTraffic1 _3      5  207.113536  0.378493
# 4              milenkoParkWithTraffic1 _4      5  207.070819  0.452193
# ..                                    ...    ...         ...       ...
# 120  milenkosRoomNearDevicesWithTraffic_5      6  188.487059  0.405644
# 121  milenkosRoomNearDevicesWithTraffic_6      6  188.782126  0.640663
# 122  milenkosRoomNearDevicesWithTraffic_7      6  189.081989  0.684329
# 123  milenkosRoomNearDevicesWithTraffic_8      6  188.790905  0.406081
# 124  milenkosRoomNearDevicesWithTraffic_9      6  188.532476  0.538261
#
#             3         4         5         6         7         8  ...  \
# 0    0.603420  0.488628  0.770314  0.578517  0.516245  0.565621  ...
# 1    0.422187  0.460770  0.557317  0.483974  0.466028  0.423438  ...
# 2    0.434815  0.488514  0.504931  0.459275  0.438444  0.303109  ...
# 3    0.293407  0.420885  0.386854  0.529839  0.413791  0.292187  ...
# 4    0.245341  0.420816  0.407300  0.547483  0.353799  0.271617  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 120  0.390501  0.370605  0.380632  0.372963  0.367048  0.296706  ...
# 121  0.511101  0.459652  0.565591  0.426825  0.398053  0.528849  ...
# 122  0.520528  0.481504  0.565737  0.293677  0.305771  0.467531  ...
# 123  0.257375  0.349634  0.397772  0.191872  0.247405  0.196023  ...
# 124  0.347124  0.438668  0.306638  0.296172  0.231941  0.206282  ...
#
#            41        42        43        44        45        46        47  \
# 0    0.364505  0.398727  0.320633  0.467987  0.342037  0.410991  0.414213
# 1    0.429531  0.261338  0.306779  0.226453  0.402260  0.333474  0.277937
# 2    0.549412  0.260054  0.239484  0.235022  0.409863  0.329590  0.283693
# 3    0.563793  0.227993  0.252353  0.252429  0.343023  0.376318  0.375788
# 4    0.482502  0.154423  0.308732  0.269272  0.368707  0.295471  0.344861
# ..        ...       ...       ...       ...       ...       ...       ...
# 120  0.287839  0.306229  0.243456  0.303520  0.378177  0.265889  0.258062
# 121  0.298694  0.241729  0.324136  0.299819  0.283583  0.448955  0.274240
# 122  0.274482  0.289981  0.326628  0.195695  0.257442  0.425451  0.306636
# 123  0.188738  0.257223  0.195581  0.271020  0.216724  0.242274  0.254045
# 124  0.321424  0.252186  0.285871  0.368995  0.311140  0.322845  0.242299
#
#            48        49        50
# 0    0.298678  0.323007  0.491290
# 1    0.245654  0.292606  0.377667
# 2    0.265905  0.290535  0.343942
# 3    0.275305  0.292688  0.371016
# 4    0.323933  0.237155  0.408515
# ..        ...       ...       ...
# 120  0.270999  0.242732  0.266028
# 121  0.346123  0.335249  0.354599
# 122  0.354090  0.301137  0.400883
# 123  0.298217  0.251187  0.255860
# 124  0.307263  0.265200  0.257155
#
# [125 rows x 52 columns]

# %%
import time
from lib import save_dataset
with open(f"{data_path}/metadata.json", 'r') as jsonfile:
    metadata = json.load(jsonfile)
    metadata['title'] = f"{version} fourier dataset"
    metadata['description'] = 'Fourier dataset with windowed test cases from '+metadata['description']
    metadata['format'] = "processed"
    metadata['author'] = 'Mihael'
    metadata['version'] = version
    metadata['created'] = int(time.time())
save_dataset(data_fourier, dataset_target_path, dataset_name = 'fourier_window', metadata=metadata)
